# %% [markdown]
# <a href="https://colab.research.google.com/github/ebenvy/DeepLearning/blob/master/TextSummarization_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from bs4 import BeautifulSoup 
from tensorflow.keras.preprocessing.text import Tokenizer 
from tensorflow.keras.preprocessing.sequence import pad_sequences
import urllib.request
np.random.seed(seed=0)

# %%
# Reviews.csv 파일을 data라는 이름의 데이터프레임에 저장. 단, 10만개의 행(rows)으로 제한.
#data = pd.read_csv("/content/drive/MyDrive/TextSummarize/Reviews_test.csv", nrows = 10000)
def merge_last(file_name, merge_after_col=9, skip_lines=0):
    with open(file_name, 'r') as fp:
        for i, line in enumerate(fp):
            if i < skip_lines:
                continue
            spl = line.strip().split(',')
            yield (*spl[:merge_after_col], ','.join(spl[merge_after_col:]))

gen = merge_last("/content/drive/MyDrive/TextSummarize/Reviews.csv")
# get the column names
header = next(gen)
# create the data frame
df = pd.DataFrame(gen, columns=header)
df.head()
df= df[:10000]
data = df[['Text','Summary']]
#df.head()

#print('전체 리뷰 개수 :',(len(data)))

# %%
data.drop_duplicates(subset=['Text'], inplace=True)
print("전체 샘플수 :", len(data))
# Out:
# 전체 샘플수 : 9452
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
print(data.isnull().sum())
# Out:
# Text       0
# Summary    0
# dtype: int64

# %%
# Null 값을 가진 샘플 제거
data.dropna(axis=0, inplace=True)
print('전체 샘플수 :',(len(data)))
# Out:
# 전체 샘플수 : 9452
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# 전처리 함수 내 사용
contractions = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not", "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not", "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is", "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would", "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would", "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam", "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock", "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is", "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as", "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would", "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have", "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have", "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are", "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are", "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is", "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have", "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have", "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have", "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have", "you're": "you are", "you've": "you have"}

# %%
# NLTK의 불용어
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
print('불용어 개수 :', len(stop_words))
print(stop_words)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# 불용어 개수 : 179
# {'against', 'this', 'our', 'herself', 'those', 'needn', 'only', "that'll", 'all', 'a', 'below', 'not', 'during', 'but', 'than', 'mightn', 'yours', "wouldn't", 'between', 'these', 'how', 'he', 'myself', 'themselves', 'itself', 'at', 's', 'is', 'ain', 'into', 'which', 'to', 'after', 'are', 'i', 'should', "isn't", 'being', 'am', 'that', "you're", 'both', 'ourselves', 'does', 'been', 'her', "weren't", 'then', "aren't", 'in', "you'll", 'his', "you've", 'up', 'yourself', 'having', 'them', 't', 'where', 'about', 'they', 'shouldn', 'and', 'have', 'while', 'now', "hadn't", 'with', 'hadn', 'do', 'wouldn', 'too', 'had', 'before', 'ma', 'further', 'on', 'wasn', 'be', 'o', "didn't", "hasn't", 'most', 'don', "needn't", 'y', 'doesn', 'for', 'himself', 'same', 'ours', 'under', 'it', 'won', "it's", 'more', 'here', 'isn', 'we', 'can', 'theirs', 'my', 'there', 'some', 'was', "should've", 've', 'couldn', "mustn't", 'mustn', 'yourselves', 'she', 'were', 'off', "couldn't", "won't", 'when', 'no', 'd', 'of', 'your', 'or', 'who', 'through', "she's", "shan't", 'very', 'if', 'haven', 'because', 'any', 'until', 'll', "don't", 'other', 'by', 'from', "shouldn't", 'will', 'whom', 'the', 'hers', 'again', 'weren', 'own', 'down', 're', "mightn't", "doesn't", 'over', 'has', "wasn't", 'did', 'once', 'so', 'shan', 'doing', 'hasn', 'above', 'you', 'him', 'few', 'm', 'nor', 'why', 'an', 'out', 'didn', 'what', 'its', 'aren', 'their', "haven't", 'such', 'as', 'just', 'me', "you'd", 'each'}

# %%
# 전처리 함수
def preprocess_sentence(sentence, remove_stopwords = True):
    sentence = sentence.lower() # 텍스트 소문자화
    sentence = BeautifulSoup(sentence, "lxml").text # <br />, <a href = ...> 등의 html 태그 제거
    sentence = re.sub(r'\([^)]*\)', '', sentence) # 괄호로 닫힌 문자열  제거 Ex) my husband (and myself) for => my husband for
    sentence = re.sub('"','', sentence) # 쌍따옴표 " 제거
    sentence = ' '.join([contractions[t] if t in contractions else t for t in sentence.split(" ")]) # 약어 정규화
    sentence = re.sub(r"'s\b","",sentence) # 소유격 제거. Ex) roland's -> roland
    sentence = re.sub("[^a-zA-Z]", " ", sentence) # 영어 외 문자(숫자, 특수문자 등) 공백으로 변환
    sentence = re.sub('[m]{2,}', 'mm', sentence) # m이 3개 이상이면 2개로 변경. Ex) ummmmmmm yeah -> umm yeah

    # 불용어 제거 (Text)
    if remove_stopwords:
        tokens = ' '.join(word for word in sentence.split() if not word in stop_words if len(word) > 1)
    # 불용어 미제거 (Summary)
    else:
        tokens = ' '.join(word for word in sentence.split() if len(word) > 1)
    return tokens

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/TextSummarize/
# Out:
# Reviews.csv  Reviews_test.csv

# %%
temp_text = 'Everything I bought was great, infact I ordered twice and the third ordered was<br />for my mother and father.'
temp_summary = 'Great way to start (or finish) the day!!!'
print(preprocess_sentence(temp_text))
print(preprocess_sentence(temp_summary, 0))
# Out:
# everything bought great infact ordered twice third ordered wasfor mother father
# great way to start the day

# %%
# Text 열 전처리
clean_text = []
for s in data['Text']:
    clean_text.append(preprocess_sentence(s))
clean_text[:5]
# Out:
# ['bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better',
#  'product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo',
#  'confection around centuries light pillowy citrus gelatin nuts case filberts cut tiny squares liberally coated powdered sugar tiny mouthful heaven chewy flavorful highly recommend yummy treat familiar story lewis lion witch wardrobe treat seduces edmund selling brother sisters witch',
#  'looking secret ingredient robitussin believe found got addition root beer extract ordered made cherry soda flavor medicinal',
#  'great taffy great price wide assortment yummy taffy delivery quick taffy lover deal']

# %%
 #Summary 열 전처리
clean_summary = []
for s in data['Summary']:
    clean_summary.append(preprocess_sentence(s, 0))
clean_summary[:5]
# Out:
# ['good quality dog food',
#  'not as advertised',
#  'delight says it all',
#  'cough medicine',
#  'great taffy']

# %%
data['Text'] = clean_text
data['Summary'] = clean_summary
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# 길이가 공백인 샘플은 NULL 값으로 변환
data.replace('', np.nan, inplace=True)
print(data.isnull().sum())
# Out:
# Text        0
# Summary    72
# dtype: int64
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4389: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
data.dropna(axis = 0, inplace = True)
print('전체 샘플수 :',(len(data)))
# Out:
# 전체 샘플수 : 9380
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
 #길이 분포 출력
text_len = [len(s.split()) for s in data['Text']]
summary_len = [len(s.split()) for s in data['Summary']]

print('텍스트의 최소 길이 : {}'.format(np.min(text_len)))
print('텍스트의 최대 길이 : {}'.format(np.max(text_len)))
print('텍스트의 평균 길이 : {}'.format(np.mean(text_len)))
print('요약의 최소 길이 : {}'.format(np.min(summary_len)))
print('요약의 최대 길이 : {}'.format(np.max(summary_len)))
print('요약의 평균 길이 : {}'.format(np.mean(summary_len)))

plt.subplot(1,2,1)
plt.boxplot(summary_len)
plt.title('Summary')
plt.subplot(1,2,2)
plt.boxplot(text_len)
plt.title('Text')
plt.tight_layout()
plt.show()

plt.title('Summary')
plt.hist(summary_len, bins=40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()

plt.title('Text')
plt.hist(text_len, bins=40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 텍스트의 최소 길이 : 4
# 텍스트의 최대 길이 : 863
# 텍스트의 평균 길이 : 35.90394456289979
# 요약의 최소 길이 : 1
# 요약의 최대 길이 : 21
# 요약의 평균 길이 : 3.561727078891258

# %%
text_max_len = 50
summary_max_len = 8

# %%
def below_threshold_len(max_len, nested_list):
  cnt = 0
  for s in nested_list:
    if(len(s.split()) <= max_len):
        cnt = cnt + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))))

# %%
below_threshold_len(text_max_len, data['Text'])
# Out:
# 전체 샘플 중 길이가 50 이하인 샘플의 비율: 0.8062899786780384

# %%
below_threshold_len(summary_max_len, data['Summary'])
# Out:
# 전체 샘플 중 길이가 8 이하인 샘플의 비율: 0.9631130063965885

# %%
data = data[data['Text'].apply(lambda x: len(x.split()) <= text_max_len)]
data = data[data['Summary'].apply(lambda x: len(x.split()) <= summary_max_len)]
print('전체 샘플수 :',(len(data)))
# Out:
# 전체 샘플수 : 7357

# %%
# 요약 데이터에는 시작 토큰과 종료 토큰을 추가한다.
data['decoder_input'] = data['Summary'].apply(lambda x : 'sostoken '+ x)
data['decoder_target'] = data['Summary'].apply(lambda x : x + ' eostoken')
data.head()
# Out:
#                                                 Text  ...                  decoder_target
# 0  bought several vitality canned dog food produc...  ...  good quality dog food eostoken
# 1  product arrived labeled jumbo salted peanuts p...  ...      not as advertised eostoken
# 2  confection around centuries light pillowy citr...  ...    delight says it all eostoken
# 3  looking secret ingredient robitussin believe f...  ...         cough medicine eostoken
# 4  great taffy great price wide assortment yummy ...  ...            great taffy eostoken
#
# [5 rows x 4 columns]

# %%
encoder_input = np.array(data['Text'])
decoder_input = np.array(data['decoder_input'])
decoder_target = np.array(data['decoder_target'])

# %%
indices = np.arange(encoder_input.shape[0])
np.random.shuffle(indices)
print(indices)
# Out:
# [6516 7048 5486 ... 1653 2607 2732]

# %%
encoder_input = encoder_input[indices]
decoder_input = decoder_input[indices]
decoder_target = decoder_target[indices]

# %%
n_of_val = int(len(encoder_input)*0.2)
print('테스트 데이터의 수 :',n_of_val)
# Out:
# 테스트 데이터의 수 : 1471

# %%
encoder_input_train = encoder_input[:-n_of_val]
decoder_input_train = decoder_input[:-n_of_val]
decoder_target_train = decoder_target[:-n_of_val]

encoder_input_test = encoder_input[-n_of_val:]
decoder_input_test = decoder_input[-n_of_val:]
decoder_target_test = decoder_target[-n_of_val:]

# %%
print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :',len(decoder_input_train))
print('테스트 데이터의 개수 :',len(encoder_input_test))
print('테스트 레이블의 개수 :',len(decoder_input_test))
# Out:
# 훈련 데이터의 개수 : 5886
# 훈련 레이블의 개수 : 5886
# 테스트 데이터의 개수 : 1471
# 테스트 레이블의 개수 : 1471

# %%
src_tokenizer = Tokenizer()
src_tokenizer.fit_on_texts(encoder_input_train)

# %%
threshold = 7
total_cnt = len(src_tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in src_tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 10726
# 등장 빈도가 6번 이하인 희귀 단어의 수: 8267
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 2459
# 단어 집합에서 희귀 단어의 비율: 77.07439865746784
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 11.098679794137391

# %%
src_vocab = 8000
src_tokenizer = Tokenizer(num_words = src_vocab) 
src_tokenizer.fit_on_texts(encoder_input_train)

# 텍스트 시퀀스를 정수 시퀀스로 변환
encoder_input_train = src_tokenizer.texts_to_sequences(encoder_input_train) 
encoder_input_test = src_tokenizer.texts_to_sequences(encoder_input_test)

# %%
print(encoder_input_train[:3])
# Out:
# [[83, 25, 281, 5736, 79, 189, 231, 47, 51, 4, 45, 829], [991, 135, 620, 1285, 146, 19, 238, 43, 331, 18, 99, 65, 252, 13, 95, 58, 453, 8, 127, 44], [5737, 1055, 689, 285, 161, 193, 307, 21, 214, 115, 165, 1, 105, 39, 8, 81, 75, 3063, 272, 359, 1286, 40, 159, 224, 3, 189, 369, 320, 747, 30, 79, 578, 1907, 965, 13, 261, 15, 261, 6, 1908, 359, 4326, 1055, 491, 100, 406, 177]]

# %%
tar_tokenizer = Tokenizer()
tar_tokenizer.fit_on_texts(decoder_input_train)

# %%
threshold = 6
total_cnt = len(tar_tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tar_tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 2957
# 등장 빈도가 5번 이하인 희귀 단어의 수: 2479
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 478
# 단어 집합에서 희귀 단어의 비율: 83.8349678728441
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 16.624531071603325

# %%
tar_vocab = 2000
tar_tokenizer = Tokenizer(num_words = tar_vocab) 
tar_tokenizer.fit_on_texts(decoder_input_train)
tar_tokenizer.fit_on_texts(decoder_target_train)

# %%
# 텍스트 시퀀스를 정수 시퀀스로 변환
decoder_input_train = tar_tokenizer.texts_to_sequences(decoder_input_train) 
decoder_target_train = tar_tokenizer.texts_to_sequences(decoder_target_train)
decoder_input_test = tar_tokenizer.texts_to_sequences(decoder_input_test)
decoder_target_test = tar_tokenizer.texts_to_sequences(decoder_target_test)

# %%
print(decoder_input_train[:5])
# Out:
# [[1, 567, 24], [1, 9, 17, 240], [1, 21], [1, 179, 29, 917, 8, 3], [1, 8, 1338, 327]]

# %%
print(decoder_target_train[:5])
# Out:
# [[567, 24, 2], [9, 17, 240, 2], [21, 2], [179, 29, 917, 8, 3, 2], [8, 1338, 327, 2]]

# %%
drop_train = [index for index, sentence in enumerate(decoder_input_train) if len(sentence) == 1]
drop_test = [index for index, sentence in enumerate(decoder_input_test) if len(sentence) == 1]

# %%
print('삭제할 훈련 데이터의 개수 :',len(drop_train))
print('삭제할 테스트 데이터의 개수 :',len(drop_test))
# Out:
# 삭제할 훈련 데이터의 개수 : 76
# 삭제할 테스트 데이터의 개수 : 43

# %%
encoder_input_train = np.delete(encoder_input_train, drop_train, axis=0)
decoder_input_train = np.delete(decoder_input_train, drop_train, axis=0)
decoder_target_train = np.delete(decoder_target_train, drop_train, axis=0)

encoder_input_test = np.delete(encoder_input_test, drop_test, axis=0)
decoder_input_test = np.delete(decoder_input_test, drop_test, axis=0)
decoder_target_test = np.delete(decoder_target_test, drop_test, axis=0)

print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :',len(decoder_input_train))
print('테스트 데이터의 개수 :',len(encoder_input_test))
print('테스트 레이블의 개수 :',len(decoder_input_test))
# Out:
# 훈련 데이터의 개수 : 5810
# 훈련 레이블의 개수 : 5810
# 테스트 데이터의 개수 : 1428
# 테스트 레이블의 개수 : 1428
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
encoder_input_train = pad_sequences(encoder_input_train, maxlen = text_max_len, padding='post')
encoder_input_test = pad_sequences(encoder_input_test, maxlen = text_max_len, padding='post')
decoder_input_train = pad_sequences(decoder_input_train, maxlen = summary_max_len, padding='post')
decoder_target_train = pad_sequences(decoder_target_train, maxlen = summary_max_len, padding='post')
decoder_input_test = pad_sequences(decoder_input_test, maxlen = summary_max_len, padding='post')
decoder_target_test = pad_sequences(decoder_target_test, maxlen = summary_max_len, padding='post')

# %%
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
embedding_dim = 128
hidden_size = 256

# 인코더
encoder_inputs = Input(shape=(text_max_len,))

# 인코더의 임베딩 층
enc_emb = Embedding(src_vocab, embedding_dim)(encoder_inputs)

# 인코더의 LSTM 1
encoder_lstm1 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4, recurrent_dropout = 0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

# 인코더의 LSTM 2
encoder_lstm2 = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

# 인코더의 LSTM 3
encoder_lstm3 = LSTM(hidden_size, return_state=True, return_sequences=True, dropout=0.4, recurrent_dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)

# %%
# 디코더
decoder_inputs = Input(shape=(None,))

# 디코더의 임베딩 층
dec_emb_layer = Embedding(tar_vocab, embedding_dim)
dec_emb = dec_emb_layer(decoder_inputs)

# 디코더의 LSTM
decoder_lstm = LSTM(hidden_size, return_sequences = True, return_state = True, dropout = 0.4, recurrent_dropout=0.2)
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state = [state_h, state_c])

# %%
# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation = 'softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_outputs) 

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 50)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 50, 128)      1024000     input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 50, 256), (N 394240      embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 50, 256), (N 525312      lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 128)    256000      input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 50, 256), (N 525312      lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 256),  394240      embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, None, 2000)   514000      lstm_3[0][0]
# ==================================================================================================
# Total params: 3,633,104
# Trainable params: 3,633,104
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
urllib.request.urlretrieve("https://raw.githubusercontent.com/thushv89/attention_keras/master/src/layers/attention.py", filename="attention.py")
from attention import AttentionLayer

# %%
# 어텐션 층(어텐션 함수)
attn_layer = AttentionLayer(name='attention_layer')
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs])

# 어텐션의 결과와 디코더의 hidden state들을 연결
decoder_concat_input = Concatenate(axis = -1, name='concat_layer')([decoder_outputs, attn_out])

# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_concat_input)

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 50)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 50, 128)      1024000     input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 50, 256), (N 394240      embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 50, 256), (N 525312      lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 128)    256000      input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 50, 256), (N 525312      lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 256),  394240      embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# attention_layer (AttentionLayer ((None, None, 256),  131328      lstm_2[0][0]
#                                                                  lstm_3[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 512)    0           lstm_3[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, None, 2000)   1026000     concat_layer[0][0]
# ==================================================================================================
# Total params: 4,276,432
# Trainable params: 4,276,432
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience = 2)
history = model.fit(x = [encoder_input_train, decoder_input_train], y = decoder_target_train, \
          validation_data = ([encoder_input_test, decoder_input_test], decoder_target_test),
          batch_size = 256, callbacks=[es], epochs = 50)
# Out:
# Epoch 1/50
# 23/23 [==============================] - 152s 6s/step - loss: 4.5366 - val_loss: 2.7086
# Epoch 2/50
# 23/23 [==============================] - 131s 6s/step - loss: 2.7831 - val_loss: 2.5114
# Epoch 3/50
# 23/23 [==============================] - 131s 6s/step - loss: 2.5977 - val_loss: 2.3714
# Epoch 4/50
# 23/23 [==============================] - 131s 6s/step - loss: 2.5054 - val_loss: 2.3229
# Epoch 5/50
# 23/23 [==============================] - 131s 6s/step - loss: 2.4317 - val_loss: 2.2907
# Epoch 6/50
# 23/23 [==============================] - 132s 6s/step - loss: 2.3511 - val_loss: 2.2792
# Epoch 7/50
# 23/23 [==============================] - 131s 6s/step - loss: 2.3067 - val_loss: 2.2594
# Epoch 8/50
# 23/23 [==============================] - 131s 6s/step - loss: 2.2680 - val_loss: 2.2791
# Epoch 9/50
# 23/23 [==============================] - 131s 6s/step - loss: 2.2412 - val_loss: 2.2634
# Epoch 00009: early stopping

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
src_index_to_word = src_tokenizer.index_word # 원문 단어 집합에서 정수 -> 단어를 얻음
tar_word_to_index = tar_tokenizer.word_index # 요약 단어 집합에서 단어 -> 정수를 얻음
tar_index_to_word = tar_tokenizer.index_word # 요약 단어 집합에서 정수 -> 단어를 얻음

# %%
# 인코더 설계
encoder_model = Model(inputs=encoder_inputs, outputs=[encoder_outputs, state_h, state_c])

# %%
# 이전 시점의 상태들을 저장하는 텐서
decoder_state_input_h = Input(shape=(hidden_size,))
decoder_state_input_c = Input(shape=(hidden_size,))

dec_emb2 = dec_emb_layer(decoder_inputs)
# 문장의 다음 단어를 예측하기 위해서 초기 상태(initial_state)를 이전 시점의 상태로 사용. 이는 뒤의 함수 decode_sequence()에 구현
# 훈련 과정에서와 달리 LSTM의 리턴하는 은닉 상태와 셀 상태인 state_h와 state_c를 버리지 않음.
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

# %%
# 어텐션 함수
decoder_hidden_state_input = Input(shape=(text_max_len, hidden_size))
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# 디코더의 출력층
decoder_outputs2 = decoder_softmax_layer(decoder_inf_concat) 

# 최종 디코더 모델
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    # 입력으로부터 인코더의 상태를 얻음
    e_out, e_h, e_c = encoder_model.predict(input_seq)

     # <SOS>에 해당하는 토큰 생성
    target_seq = np.zeros((1,1))
    target_seq[0, 0] = tar_word_to_index['sostoken']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition: # stop_condition이 True가 될 때까지 루프 반복

        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = tar_index_to_word[sampled_token_index]

        if(sampled_token!='eostoken'):
            decoded_sentence += ' '+sampled_token

        #  <eos>에 도달하거나 최대 길이를 넘으면 중단.
        if (sampled_token == 'eostoken'  or len(decoded_sentence.split()) >= (summary_max_len-1)):
            stop_condition = True

        # 길이가 1인 타겟 시퀀스를 업데이트
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # 상태를 업데이트 합니다.
        e_h, e_c = h, c

    return decoded_sentence

# %%
# 원문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2text(input_seq):
    temp=''
    for i in input_seq:
        if(i!=0):
            temp = temp + src_index_to_word[i]+' '
    return temp

# 요약문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2summary(input_seq):
    temp=''
    for i in input_seq:
        if((i!=0 and i!=tar_word_to_index['sostoken']) and i!=tar_word_to_index['eostoken']):
            temp = temp + tar_index_to_word[i] + ' '
    return temp

# %%
for i in range(500, 1000):
    print("원문 : ",seq2text(encoder_input_test[i]))
    print("실제 요약문 :",seq2summary(decoder_input_test[i]))
    print("예측 요약문 :",decode_sequence(encoder_input_test[i].reshape(1, text_max_len)))
    print("\n")
# Out:
# 원문 :  somehow previous review got live houston tx buy lots bottled water cannot tell difference bottle talking rain glass cold water
# 실제 요약문 : just water nothing more
# 예측 요약문 :  great
#
#
# 원문 :  way overpriced shipping charges mind paying lot quality treat dogs real problem companies price shipping charges obviously enough get amount money treats also make money shipping charges way cost ship lb bag treats dollars would fair reason gave stars instead
# 실제 요약문 : great treat
# 예측 요약문 :  great
#
#
# 원문 :  saw made interesting process decided give try really enjoy flavor adds looking forward trying several dishes thanks brewed
# 실제 요약문 : outstanding product
# 예측 요약문 :  great
#
#
# 원문 :  best sugar substitute time virtually replacing sugar home bakes sugar aftertaste cannot wait go mainstream able buy supermarkets
# 실제 요약문 : the best sugar substitute
# 예측 요약문 :  not not the the it
#
#
# 원문 :  received product old dried makes good product buy time dog loves supplier pay attention ship
# 실제 요약문 : out bone
# 예측 요약문 :  not not the the it
#
#
# 원문 :  st cup coffee getting grounds coffee every cups problem cup manufactures reorder
# 실제 요약문 : defective
# 예측 요약문 :  great
#
#
# 원문 :  tried many brands hot chocolates far best realize percent cheaper use package buy store add water want impress product
# 실제 요약문 : delicious
# 예측 요약문 :  great
#
#
# 원문 :  great beans price live big city however would suggest buying green beans local ethiopian shop even community also remember pea berry east outstanding pea berry comparable standard beans
# 실제 요약문 : great price
# 예측 요약문 :  great
#
#
# 원문 :  work short time need dissolve tongue let fun begin
# 실제 요약문 : miracle fruit tablets
# 예측 요약문 :  great
#
#
# 원문 :  love puck flavors vienna blend nice medium roast strong wonderful flavor without flavored coffee one favorites
# 실제 요약문 : yummy coffee
# 예측 요약문 :  great
#
#
# 원문 :  trouble storing fresh basil learned long time ago put fridge cat attracted anything plant family keeps basil fresh cat
# 실제 요약문 : keeps on the cat
# 예측 요약문 :  great
#
#
# 원문 :  like even regular bisquick mix make pancakes taste closer scratch wheat flour pancakes members family tried yet used pizza crust biscuits
# 실제 요약문 : just about perfect for pancakes
# 예측 요약문 :  great
#
#
# 원문 :  wow like flavors tried apple pie mint ice cream strawberry others great love apple pie key lime says hydrogenated starch oils difference
# 실제 요약문 : key lime gum
# 예측 요약문 :  great
#
#
# 원문 :  usually make fondant decided give one try absolute pleasure working fondarific wedding white since cold moment fondant arrived stone hard break apart knife heat microwave ten seconds great working im say fondant easy roll cover two cake
# 실제 요약문 : fantastic
# 예측 요약문 :  great
#
#
# 원문 :  kettle chips look feel taste like lays chips used favorite crinkle cut longer favorite
# 실제 요약문 : surprise it is different
# 예측 요약문 :  great
#
#
# 원문 :  jar much smaller imagined via pictures thought going size jar instead much smaller spicy though lots jalapeno lot honey mustard
# 실제 요약문 : small but spicy
# 예측 요약문 :  not not the the it
#
#
# 원문 :  product seems replaced similar previous product previous pink color texture better finding elsewhere new product much like competitors selling enjoyed products spice lab disappointed product
# 실제 요약문 : product changed
# 예측 요약문 :  not not the the the the the
#
#
# 원문 :  one products spoiled really appreciate look sometimes find cheaper elsewhere product com often offer email kitties like elegant basically refuse else like stuck spending dough feed oh well
# 실제 요약문 : my cats love this
# 예측 요약문 :  great
#
#
# 원문 :  thought post review response bad cat ordered batch holiday reasons effects coffee great tart aftertaste matter strong brew reason gave four stars would personally liked litter darker roast wanted say drank lot bad cat year christmas eve christmas zero headaches ill might something else
# 실제 요약문 : no problems from same batch
# 예측 요약문 :  great
#
#
# 원문 :  dissapointed fondant decided try first time mistake claim fondant rolled thinner brands use less decorate true even tends tear finally got cake cover hard smooth around cake sticky fondant smoother smoothly never buy brand going stick wilton
# 실제 요약문 : very
# 예측 요약문 :  great
#
#
# 원문 :  taste great berries melted may order winter order cold weather enjoy flavor
# 실제 요약문 : order only in cold
# 예측 요약문 :  not not the the it
#
#
# 원문 :  ordered salt collection husband christmas gift absolutely loves used every night since great gift anyone enjoys cooking ordering second collection soon
# 실제 요약문 : excellent gift for any cook
# 예측 요약문 :  great
#
#
# 원문 :  purchased girlfriend loved stuff xmas period supply last several months
# 실제 요약문 : best hot chocolate ever
# 예측 요약문 :  great
#
#
# 원문 :  candy machine works fine finger hole small adult fingers candy lover small amount
# 실제 요약문 : great little
# 예측 요약문 :  great
#
#
# 원문 :  says box drink contains bananas sports drink might seem little high priced go store buy bananas sports drinks pay get nutrition get juice box coconut water
# 실제 요약문 : excellent
# 예측 요약문 :  not not the the the the the
#
#
# 원문 :  discovered nuts accident clearance ay local cvs wish bought cinnamon brown sugar flavor perfect together roasted almond flavor candy coated like cinnamon almonds everyone shared think highly recommend product one tasty healthy snacks find wish amazon would put subscribe save program
# 실제 요약문 : simply the best
# 예측 요약문 :  great
#
#
# 원문 :  excited see gluten free bisquick grandmother mother used remember strawberry first thing made almost cried good since made pancakes baked chicken regular web site com great recipes thank bisquick
# 실제 요약문 : wow pancake at last
# 예측 요약문 :  not not the the the the the
#
#
# 원문 :  discovered moved canada years back experienced thicker wasa crispbread bit put first feelings dissolved first time ate one light laughing cow cheese little powdery would like compliment cheeses well without overwhelming
# 실제 요약문 : for those who want the
# 예측 요약문 :  great
#
#
# 원문 :  let start saying family loves stuff fairly strong flavor vanilla cooks light problem product recent price increase good product fair price pricey would suggest order least taste good pancakes supposed taste like would suggest playing
# 실제 요약문 : pretty darn good but at an increased cost
# 예측 요약문 :  great
#
#
# 원문 :  know anything went known recipe found mix fruit peppers vinegar thought different form wrong
# 실제 요약문 : not happy with the product
# 예측 요약문 :  not not the the it
#
#
# 원문 :  kind ripoff bought theater box instead piece candy bar version turned big mistake box pieces filled even piece flavor one box green pieces black better value pack original piece bar theater box sold weight volume box empty ripoff
# 실제 요약문 : box but not good value
# 예측 요약문 :  the not it
#
#
# 원문 :  good flavor resemble oreo purchased along chips ahoy resemble flavor chips ahoy opinion tasted like animal crackers stick chips ahoy calorie packs
# 실제 요약문 : these are ok
# 예측 요약문 :  great
#
#
# 원문 :  usually pineapple coconut drinks drink taste great taste resemble anything close pina colada flavor actually difficult taste pineapple coconut tastes tangy little sour like water bit sugar sour ness yeah really taste crave sure everyone reaction drink appeal really wanted like though said usually love pineapple coconut drinks
# 실제 요약문 : just did not taste good to me
# 예측 요약문 :  great
#
#
# 원문 :  favorite progresso soup broth excellent flavor salty yes veggies could bit pieces large tasty heat already usually add shots hot sauce suit taste really want indulge chop pieces smoked sausage add heating heaven
# 실제 요약문 : good soup on cold
# 예측 요약문 :  not not it
#
#
# 원문 :  best licorice ever least best ever problem pack gone hard concentrate work go panda cannot think anything panda
# 실제 요약문 : for more panda
# 예측 요약문 :  great
#
#
# 원문 :  like coffee bought christmas present smells like milk shake might try might make coffee drinker
# 실제 요약문 : great aroma
# 예측 요약문 :  great
#
#
# 원문 :  found crisps local walmart figured would give try yummy may never go back regular chips big chip fan anyway problem eat entire bag one sitting give crisps big thumbs
# 실제 요약문 : yummy
# 예측 요약문 :  great
#
#
# 원문 :  month old eats food time bought variety pack noticed peach oatmeal thick like paste thinking feeding started choking air could give luckily started crying jars went right garbage
# 실제 요약문 : old on oatmeal
# 예측 요약문 :  great
#
#
# 원문 :  really taste like much able add sauce without flavor however could get past texture would rather chew
# 실제 요약문 : gross texture
# 예측 요약문 :  great
#
#
# 원문 :  one best salsas found long time stay away variety pack two come worth money
# 실제 요약문 : love the salsa
# 예측 요약문 :  not not it
#
#
# 원문 :  drawer awesome holding cups boxes get nearly empty seems pointless store shelf keeps cups nice dry handy best machine rest safely top giving little area kitchen kind like little break room love shelf bought hang wall hold boxes
# 실제 요약문 : this thing is awesome
# 예측 요약문 :  great
#
#
# 원문 :  traditional english muffins usually fat free little fat little called something else together closer would say buttery taste fat go terrific looking english muffin looking would rather save fat chocolate dessert
# 실제 요약문 : watch out for the fat
# 예측 요약문 :  great
#
#
# 원문 :  like product unique taste enough spiciness sweetness make different goes virtually anything tried cooking imagine would add lot stews soups etc keeps well last bottle got lost pantry several years old found still tasted great along sauce catsup etc condiment staple
# 실제 요약문 : really different really good
# 예측 요약문 :  great
#
#
# 원문 :  dog service dog kind woods lots good training tool treat plus share dog see fit
# 실제 요약문 : very dog treat
# 예측 요약문 :  great
#
#
# 원문 :  herbal additives blend destroy real tea taste people like herbal taste
# 실제 요약문 : not real tea
# 예측 요약문 :  great
#
#
# 원문 :  cashews best ever containers come perfect size
# 실제 요약문 : great
# 예측 요약문 :  great
#
#
# 원문 :  low calorie satisfying soups nice fill want much want hungry hours
# 실제 요약문 : yum
# 예측 요약문 :  great
#
#
# 원문 :  first ghee ever used cooking tastes really pure one amazon thats usda organic hence higher price going try different one see one compares one organic
# 실제 요약문 : great taste
# 예측 요약문 :  great
#
#
# 원문 :  get enough package make good size cup drink consistent flavor amount get packet purchased couple times
# 실제 요약문 : nice product
# 예측 요약문 :  great
#
#
# 원문 :  best buy flaxseeds opposed flaxseed oil meal get omega since grinding seeds released omega oils freshest recommend storing flaxseeds freezer keep open well grind tablespoons coffee grinder add yogurt protein shake good stuff
# 실제 요약문 : great source for
# 예측 요약문 :  great
#
#
# 원문 :  yuban coffee choice years price amazon good recommend product coffee lover
# 실제 요약문 : you cannot beat yuban
# 예측 요약문 :  great
#
#
# 원문 :  doctor told must eat hulless popcorn popcorn cannot give favorite snack bought wabash farms amish country popcorn kernels tiny pop well although big fluffy popcorn get grocery store tastes great however fewer smaller hulls think thing completely hulless notice get hulls stuck teeth anymore
# 실제 요약문 : very good
# 예측 요약문 :  great
#
#
# 원문 :  fabulous tasty awful already recommended folks work continue purchase
# 실제 요약문 : eat without
# 예측 요약문 :  great
#
#
# 원문 :  every bit good vermont maple syrups opinion may know grade maple syrup stronger flavor grade prefer grade version looks like amazon stock writing hopefully get soon quite good also well priced
# 실제 요약문 : yum
# 예측 요약문 :  great
#
#
# 원문 :  best beer sausages come across decades taste like old time sausages used get bars younger wont take word ask friends
# 실제 요약문 : the best
# 예측 요약문 :  not not the the it
#
#
# 원문 :  taste powder packs grocery store like ok anything great hot water easy make powder packs home cost go back method save coffee
# 실제 요약문 : not bad
# 예측 요약문 :  great
#
#
# 원문 :  easy looks came enough yellow frosting frosting stick well year old like making though
# 실제 요약문 : not as easy as it looks
# 예측 요약문 :  great
#
#
# 원문 :  love weaver coffee one best gourmet coffee would recommend coffee coffee lover
# 실제 요약문 : love this coffee
# 예측 요약문 :  great
#
#
# 원문 :  third child first son born sent oldest school friends celebrate really made feel important school helped celebrate birth little boy loved friends enjoyed btw clear school first hate mail please
# 실제 요약문 : fun for our daughter
# 예측 요약문 :  great
#
#
# 원문 :  order arrived advertised chances use awesome flavor exactly hoped may take finish entire gallon order
# 실제 요약문 : sesame oil
# 예측 요약문 :  not not it
#
#
# 원문 :  family loves three flavors dark chocolate favorite price unbeatable buy product
# 실제 요약문 : great hot cocoa
# 예측 요약문 :  great
#
#
# 원문 :  trying many hot cocoa cup options find grove square product tastes best personal taste find brewing medium cup size setting best taste add minature marshmellows great treat however hot chocolate may turn
# 실제 요약문 : best tasting cocoa cup available
# 예측 요약문 :  great
#
#
# 원문 :  coffee surprisingly delicious never problem cups bursting maybe coffee brewer coffee bit less strong normally prefer coffee makes great taste look forward mug every morning would definitely recommend buy
# 실제 요약문 : yummy hazelnut
# 예측 요약문 :  great
#
#
# 원문 :  course prefer freshly made espresso sometimes instant good pinch travel around europe several brands available bad brand ok using coffee flavoring etc beverage rates rock bottom book
# 실제 요약문 : this stuff is nasty
# 예측 요약문 :  great
#
#
# 원문 :  together many customers frustrated tassimo starbucks ended coffee verona since time tried various alternatives limited degrees success reading previous review sent supply test love point giving tassimo machine away great start new year
# 실제 요약문 : this is the verona replacement
# 예측 요약문 :  great
#
#
# 원문 :  wolfgang puck hawaiian hazelnut coffee keurig brewer good medium strength coffee hazelnut flavor full body enjoyable anytime day really like coffee
# 실제 요약문 : wolfgang puck hazelnut cup coffee
# 예측 요약문 :  great
#
#
# 원문 :  actual product good would rate item however one dollar local grocery twenty eight dollars per twelve pack running almost two half dollars said expensive sigh really hoping get something local cost take care lee
# 실제 요약문 : too expensive
# 예측 요약문 :  not not the the the it
#
#
# 원문 :  paid extra money sister turns arrived day late unacceptable
# 실제 요약문 : shipment
# 예측 요약문 :  great
#
#
# 원문 :  never oberto brand excellent deal especially gift subscription every two months dad essentially supply oberto cocktail pepperoni stuff tastes good may steal
# 실제 요약문 : excellent product and deal
# 예측 요약문 :  not not it
#
#
# 원문 :  really love oatmeal lovely treat quick easy prepare delicious ingredient smoothies even must buy
# 실제 요약문 : delicious
# 예측 요약문 :  great
#
#
# 원문 :  really nice rich tasting maple syrup new maple syrup try grade authentic flavor thicker lighter grades goes farther pancakes recipes
# 실제 요약문 : excellent
# 예측 요약문 :  great
#
#
# 원문 :  looking years glad finally found like remembered childhood
# 실제 요약문 : just like
# 예측 요약문 :  great
#
#
# 원문 :  much worse first time bought tea amazon used get directly revolution tea know made difference change tea composition used wife favorite tea metallic smell aftertaste much less pomegranate flavor strong almost cheap generic green tea flavor really disappointing especially since stuck six boxes
# 실제 요약문 : tastes different
# 예측 요약문 :  great
#
#
# 원문 :  cup flavors many good ones one least favorites tried almost much flavor one even add various types creamers course matter taste one taste good bad kind like generic coffee try something else instead
# 실제 요약문 : not my favorite
# 예측 요약문 :  great
#
#
# 원문 :  brought box visit daughter family fiber gourmet light much
# 실제 요약문 : thought it was exceptional
# 예측 요약문 :  great
#
#
# 원문 :  gluten sensitive individual false sense read simple ingredients amazon info page first homework read labels began consuming ended massive attack wanted let everyone sensitivities allergies avoid product
# 실제 요약문 : contains msg and
# 예측 요약문 :  not not the the the the the
#
#
# 원문 :  dark single serve cup use keurig every day friend gave us sample went crazy best hot chocolate ever highly recommend treat evening take place dessert
# 실제 요약문 : grove square hot cocoa cups
# 예측 요약문 :  great
#
#
# 원문 :  product great first dogs love get time morning go crazy take bag one dogs bad allergies eat certain foods specifically lamb rice chemical fillers happy hips fit bill quite wholesome dogs getting bit years also good get dose glucosamine condroitin
# 실제 요약문 : this is terrific product
# 예측 요약문 :  great
#
#
# 원문 :  gave erin baker breakfast morning glory cookies gift gave cookies high reviews thank
# 실제 요약문 : the best breakfast cookies
# 예측 요약문 :  great
#
#
# 원문 :  dogswell best treats dogs wholesome ingredients free chemicals hormones even finicky dogs love always several varieties hand amazon one best places found buy reasonable price free shipping excellent product highly recommended
# 실제 요약문 : the treat for dogs
# 예측 요약문 :  great
#
#
# 원문 :  really like product seen around awhile glad amazon carries buttery taste calorie popcorns little unpopped kernels perfect serving size bags
# 실제 요약문 : best calorie popcorn
# 예측 요약문 :  great
#
#
# 원문 :  really normal taste coffee would buy finish one fact still sleepy drinking two cups
# 실제 요약문 : after
# 예측 요약문 :  great
#
#
# 원문 :  formula great works wonders baby spits expensive oz cans oz buy oz store less almost double price get
# 실제 요약문 : too expensive to buy here
# 예측 요약문 :  great
#
#
# 원문 :  big fan eating microwave popcorn friend mine suggested pork thought crazy little know best microwave snack ever long time chose microwave popcorn pork rinds
# 실제 요약문 : best snack ever ate
# 예측 요약문 :  not not the the the the the
#
#
# 원문 :  hi coffee smell taste great recommend senseo vienna still packages paris nobody wanna drink guess throw away
# 실제 요약문 : smells and tastes funny
# 예측 요약문 :  great
#
#
# 원문 :  past able make many different cakes using cake mix made rum cakes today thinking done something wrong first one turn usual realize anything wrong duncan hines something wrong reducing size product would gladly paid larger mix never buy another dunkin hines mix think
# 실제 요약문 : an old friend
# 예측 요약문 :  not not it
#
#
# 원문 :  produce extremely fresh made delicious thai soup items plenty spare
# 실제 요약문 : excellent
# 예측 요약문 :  not not it
#
#
# 원문 :  open close smoothly looks good open close smoothly drawer feet fit bottom unit track tray sticks lot hold top unit jerk drawer
# 실제 요약문 : looks good
# 예측 요약문 :  great
#
#
# 원문 :  always strict peet coffee lover switch brands weaver heart taste clean strong correct even packaging still caffeinated heart
# 실제 요약문 : make my day
# 예측 요약문 :  great
#
#
# 원문 :  plain simple buy drawer set coffee maker top done easy get cups whenever brewing coffee right
# 실제 요약문 : very neat drawer for you coffee
# 예측 요약문 :  great
#
#
# 원문 :  great product surprise local shelves often cleared especially early season purchasing bulk amazon com dependable alternative form roses flowers insecticide weeks need separate disease would something one would apply anything edible assures product safe
# 실제 요약문 : combo rose food
# 예측 요약문 :  great
#
#
# 원문 :  firm small pieces intense licorice flavor love black licorice trying different gluten free options ordering one
# 실제 요약문 : licorice flavor
# 예측 요약문 :  great
#
#
# 원문 :  tried many different brands rose jams disappointed sweet little flower flavoring glad found brand rose tastes exactly subtle aroma rose great alone toast paired cream cheese cheese even scoop good brand vanilla ice cream creative delicious
# 실제 요약문 : absolutely the best
# 예측 요약문 :  great
#
#
# 원문 :  imho simply better beverage earth since need add words see prior
# 실제 요약문 : world best drink
# 예측 요약문 :  great
#
#
# 원문 :  organic peta list free brands know leading brands dog foods conduct horrible dogs plus delivered door shipping charge costs less product used buy saving time money oh yeah dogs love newman organics adult dog food formula pound bag
# 실제 요약문 : newman own organic dog food
# 예측 요약문 :  great
#
#
# 원문 :  love getting something new diet tried plain added cubed chicken broccoli really good everything tried namaste wonderful keep coming new things foods gluten free say cheez pasta dish ounce bags
# 실제 요약문 : great with chicken and
# 예측 요약문 :  great
#
#
# 원문 :  delicious tea light sweet aftertaste highly recommend tea drinkers want black tea one strong bitter needs additional sweetening
# 실제 요약문 : tea
# 예측 요약문 :  great
#
#
# 원문 :  way make darn good cup green tea skeptical cup tea brewed close
# 실제 요약문 : great green tea
# 예측 요약문 :  great
#
#
# 원문 :  love coffee pods love fact amazon sells bulk thanks
# 실제 요약문 : coffee pods
# 예측 요약문 :  great
#
#
# 원문 :  never bought vanilla beans seen store dry crusty looking beans vacuum sealed still moist smelled great whole pantry smelled wonderful put made homemade vanilla bean ice cream vanilla ice cream ever run absolutely buy
# 실제 요약문 : great beans
# 예측 요약문 :  great
#
#
# 원문 :  key lime pie one time favorite desserts heard gum definitely figured would taste like standard citrus mint gum wrong definitely tastes like real key lime pie filling actual key lime flavor milk sweet taste overpowering flavor actually lasts quite try
# 실제 요약문 : tastes like the real thing
# 예측 요약문 :  the not it
#
#
# 원문 :  chips incredible enough cannot said better potato chips without guilt fat calories
# 실제 요약문 : deliciousness for little calories
# 예측 요약문 :  great
#
#
# 원문 :  earthy tasting ok rice cooks fairly well cooker good tho taste really earthy mind much almost strong tasting
# 실제 요약문 : ok
# 예측 요약문 :  great
#
#
# 원문 :  seems best brand tried others weak flavor one would truly recommend moms small children need hot chocolate playing snow grab marshmellows enjoy
# 실제 요약문 : dark chocolate cocoa
# 예측 요약문 :  great
#
#
# 원문 :  much say product hype carefully followed directions packaging mberry miracle fruit tablets results one potato chips face mary sorry miracles one make show
# 실제 요약문 : on the hype save some
# 예측 요약문 :  great
#
#
# 원문 :  dog loves treats smell taste special treats healthy mildly chewy low calorie treats perfect good compliment regular chicken jerky treats usually pieces training
# 실제 요약문 : healthy tasty treat
# 예측 요약문 :  great
#
#
# 원문 :  packaging fine baby food rotten however amazon com let return right put food packaging review page buyers take look
# 실제 요약문 : the food was
# 예측 요약문 :  great
#
#
# 원문 :  expectations grove square hot chocolate tasty searching swiss miss brand search pulled one price right ordered expectations pleasantly surprised grove squares wonderful chocolate creamy taste even large cup setting
# 실제 요약문 : product
# 예측 요약문 :  great
#
#
# 원문 :  like find grinder bottle convenient like taste would definitely buy considering healthy use sure
# 실제 요약문 : sea salt
# 예측 요약문 :  great
#
#
# 원문 :  disappointed product thought would bigger also come enough icing use
# 실제 요약문 : disappointment
# 예측 요약문 :  not not the the it
#
#
# 원문 :  big fan sorghum flour baked goods gives everything bit adds extra bit sweet baking highly recommend baking flour mixes may want add savory recipes though light sweet flavor
# 실제 요약문 : best for
# 예측 요약문 :  great
#
#
# 원문 :  ordered cases different dates got within days cant find stores please keep stock make great meal veggies salad type fish omega good
# 실제 요약문 : taste great and good for you
# 예측 요약문 :  great
#
#
# 원문 :  happy quick shipping needed school product daughter came roof broken corner house broken could send back needed project
# 실제 요약문 : shipping
# 예측 요약문 :  great
#
#
# 원문 :  sent tea delicious continue use company great enthusiasm
# 실제 요약문 : one of the best
# 예측 요약문 :  great
#
#
# 원문 :  small expensive bag thinking lb would lot actually came especially since starch somewhat light since wish sold larger quantities
# 실제 요약문 : good company and quality
# 예측 요약문 :  great
#
#
# 원문 :  diabetic like artificial sugar really like hot chocolate sweet enough also enough chocolate flavor love
# 실제 요약문 : yummy
# 예측 요약문 :  great
#
#
# 원문 :  bought brand horrible amazon needs source offer ladies brand wrappers superior anything market today
# 실제 요약문 : amazon please brand rice
# 예측 요약문 :  great
#
#
# 원문 :  gourmet corn smaller kernels like would probably buy special oil stir crazy popper every kernel pops every time probably return good old time
# 실제 요약문 : small pops
# 예측 요약문 :  not not it
#
#
# 원문 :  local diner eat regularly use kinds foods love hot without flavor like sauces burn taste burn awesome flavor surprised find amazon would highly recommend anyone likes good hot sauce
# 실제 요약문 : love this stuff
# 예측 요약문 :  great
#
#
# 원문 :  got two teas one type iced coffe rest holiday coffees apple cider spicy eggnog gingerbread bait redeeming factor amazon great issued refund
# 실제 요약문 : not what ordered
# 예측 요약문 :  great
#
#
# 원문 :  many others noted treats made dog extremely ill could figure wrong first eventually realized treats might making sick stopped feeding happy hips almost immediately got better threw stay far away product
# 실제 요약문 : product
# 예측 요약문 :  great
#
#
# 원문 :  really like tea started drinking suggestion friend helps upset buying future
# 실제 요약문 : this is great tea
# 예측 요약문 :  great
#
#
# 원문 :  great coffee dark bitter little chocolaty reminds get better price caribou coffee store however
# 실제 요약문 : yum
# 예측 요약문 :  great
#
#
# 원문 :  consistency grain free chicken turkey lamb fish formula poop much water cat food two cats went case short time put water cat food poor value manufacturer water product call oz provide nothing like come know expect brands
# 실제 요약문 : poor value for the money
# 예측 요약문 :  great
#
#
# 원문 :  prunes saved many baby constipation days started solids seems easier consume juice used give baby yogurt soon became favorite food symptoms highly recommend product parents hard time babies constipation
# 실제 요약문 : to go to for baby constipation
# 예측 요약문 :  great
#
#
# 원문 :  mccann instant irish oatmeal variety pack regular apples cinnamon maple brown sugar count boxes fan mccann steel cut oats thought would give instant variety try found hardy meal sweet great folks like need food palatable easily fiber make bloat
# 실제 요약문 : satisfying
# 예측 요약문 :  great
#
#
# 원문 :  dog loves treats yorkie right size let friend give dog loved also
# 실제 요약문 : best bones
# 예측 요약문 :  great
#
#
# 원문 :  really liked hot sauce incredibly hot perfect friends looking something like complaint bit hard cooking find good balance hot flavor heat flavor almost perfect
# 실제 요약문 : hot
# 예측 요약문 :  great
#
#
# 원문 :  good good standard coconut water brand container smaller like taste plain one better ok
# 실제 요약문 : plain is better
# 예측 요약문 :  great
#
#
# 원문 :  like cracker good little fill meals
# 실제 요약문 : good snack
# 예측 요약문 :  great
#
#
# 원문 :  three chihuahuas love treat good expensive stores glad found amazon much lower price
# 실제 요약문 : great price for favorite treat
# 예측 요약문 :  great
#
#
# 원문 :  best iced green tea ever hint blueberry perfect add bit stevia little sweetness would call instant tea carry packet purse better prepared tea could buy eating stash tea always good extraordinary
# 실제 요약문 : perfect summer tea
# 예측 요약문 :  great
#
#
# 원문 :  food get pet store delivered door price slightly less
# 실제 요약문 : so convenient
# 예측 요약문 :  great
#
#
# 원문 :  first time cracked open box bisquick gluten free made batch pancakes surprised delicious perhaps best pancakes ever make couple modifications box recipe instead using oil use amount melted butter add fresh blueberries pancake cooking serve whipped cream great looking forward trying recipes including pizza crust
# 실제 요약문 : bisquick gf so delicious
# 예측 요약문 :  not not the the it
#
#
# 원문 :  best treats dog matter large small give local society well dont option purchasing hi quality treats dog loves small dogs think steaks nearly jump ft piece dry break easily put pocket without concerns residue transfer favorite dogs
# 실제 요약문 : best treats
# 예측 요약문 :  great
#
#
# 원문 :  searched hot chocolate keurig could find economical purchase found decent price glad husband absolutely loves hot chocolate says reminds childhood try like
# 실제 요약문 : love this hot chocolate
# 예측 요약문 :  great
#
#
# 원문 :  opened bar harbor clam chowder could believe clams chowder mostly potatoes
# 실제 요약문 : bar harbor where are the
# 예측 요약문 :  not not the the the the the
#
#
# 원문 :  like loose tea hate clean metal holders bags ideal let make pot cup tea throw reused garden
# 실제 요약문 : tea loose leaf tea bags
# 예측 요약문 :  great
#
#
# 원문 :  alteration formula treats taste like first used pour mouth since wrapped smaller packages three sticks lot longer
# 실제 요약문 : stix shows you to the
# 예측 요약문 :  great
#
#
# 원문 :  excellent quality product reminds italy without caffeine perfect dinner without effects much caffeine
# 실제 요약문 : decaf espresso
# 예측 요약문 :  great
#
#
# 원문 :  coffee general wolfgang variety alright however expecting creme caramel taste something similar feel delivered tried multiple cups different cup sizes coffee flavored coffee yet could taste anything beyond flavor coffee
# 실제 요약문 : misleading flavor name
# 예측 요약문 :  great
#
#
# 원문 :  discovered gluten months ago dismayed horrible gluten free foods market since found substitute foods acceptable bisquick gluten free pancake baking mix one use every sunday make either pancakes waffles recommend mix whole heartedly
# 실제 요약문 : love this product
# 예측 요약문 :  not not the the the the the
#
#
# 원문 :  makes perfect delicious crisp outside soft inside waffles minutes worth every penny
# 실제 요약문 : delicious waffles in
# 예측 요약문 :  great
#
#
# 원문 :  product complete disappointment tastes like mushy pineapple taste
# 실제 요약문 : tastes like mushy pineapple
# 예측 요약문 :  not not the the the it
#
#
# 원문 :  love delicious mangoes subscription option ship correct times received two shipments week one shipments supposed april notified shipped charged card
# 실제 요약문 : does not work well
# 예측 요약문 :  great
#
#
# 원문 :  soon got bag decaf made big mug filled house wonderful aroma high quality fresh brewed coffee finely ground still used amount normally turned great added soy milk sat back enjoyed rare treat coffee break definitely buy winter months treat excellent hot coffee time day night
# 실제 요약문 : best decaf ever
# 예측 요약문 :  great
#
#
# 원문 :  love treats two german think treats great even large size dogs dogs absolutely go crazy calories per treat perfect training also love texture put pocket without ton gross smell product also ingredient list opposed many dog treats pronounce ingredients list know getting
# 실제 요약문 : these are amazing
# 예측 요약문 :  great
#
#
# 원문 :  good product limited cannot eat use salad dressing pleased find bulk great price good taste
# 실제 요약문 : good price
# 예측 요약문 :  not not it
#
#
# 원문 :  okay doctor order read lot benefits love adding smoothies etc product came fresh definitely good buy ordering
# 실제 요약문 : just what the ordered
# 예측 요약문 :  not not the the the the the
#
#
# 원문 :  coffee good however least half sealed correctly brew edge foil pops open coffee grounds go everywhere fun clean may batch got ordering
# 실제 요약문 : poorly
# 예측 요약문 :  great
#
#
# 원문 :  amazon back daughter started low carb diet searching snack lowrey micro pork rinds really fit bill enjoy snack diet loves
# 실제 요약문 : great snack product from amazon
# 예측 요약문 :  great
#
#
# 원문 :  love snacks whole grain organic also love fact spill everywhere snack cup like cheerios also noticed leave lot crumbs makes mommy happy
# 실제 요약문 : yummy and clean
# 예측 요약문 :  great
#
#
# 원문 :  purchased special gift really enjoyed appreciated receiving unusual gift received item good shape quickly pleased everything order
# 실제 요약문 : chocolate liquor excellent
# 예측 요약문 :  not not it
#
#
# 원문 :  bad returned children even like difficult please comes sweet drinks food
# 실제 요약문 : not good
# 예측 요약문 :  great
#
#
# 원문 :  love product adds flavor water without nasty artificial sweetners hope product stay
# 실제 요약문 : refreshing to water
# 예측 요약문 :  great
#
#
# 원문 :  peach nectar tasty natural fruit drink loaded sugar looking alternative orange juice tolerate calories might want give drink try also makes nice ingredient mixed alcoholic beverages peach
# 실제 요약문 : tasty drink
# 예측 요약문 :  not not the the it
#
#
# 원문 :  horses love sweet reward dots hold together nicely reward bag
# 실제 요약문 : sweet
# 예측 요약문 :  great
#
#
# 원문 :  coffee strong enough tastes use cream sure makes difference
# 실제 요약문 : not my cup of coffee
# 예측 요약문 :  great
#
#
# 원문 :  eat junk food would like enjoy guilty pleasure cookies neither healthy tasty stick chewy chocolate chip cookies
# 실제 요약문 : gross cookies
# 예측 요약문 :  great
#
#
# 원문 :  found chia seeds actually bought bag could plant seeds growing like discovered great foods also husband put tomato sauce thicken add cereal tablespoon lemonade fun eat take flavor ever making
# 실제 요약문 : love the chia seeds
# 예측 요약문 :  not not the the the the the
#
#
# 원문 :  packages sent order pack sent order problem company fixed right away make thanks handling situation quickly
# 실제 요약문 : there was problem with the order
# 예측 요약문 :  not not it
#
#
# 원문 :  twizzlers brand licorice much better well known brand get package free good deal black cherry good taste strawberry taste delicate barely
# 실제 요약문 : good licorice
# 예측 요약문 :  great
#
#
# 원문 :  issues product pods sealed properly grounds spill wasteful pod individually sealed would rather packaged like senseo pods pods really fit senseo coffee maker fat single small double causes problems sometimes brew cup plus side price
# 실제 요약문 : just ok
# 예측 요약문 :  not not it
#
#
# 원문 :  great way get tast childhood without sugar even without blood sugar problems want cut back excess sugar allows drink option taste low calorie sugar free parents dont tell kids serve never know good
# 실제 요약문 : taste of
# 예측 요약문 :  great
#
#
# 원문 :  could find local shell gas station source buy want fast delivery price great order etc
# 실제 요약문 : love these smokies
# 예측 요약문 :  great
#
#
# 원문 :  husband pretzel lover become addicted see draw potato chip local stores stock occasionally tried flavors like jalapeno like back nice able buy run town looking
# 실제 요약문 : thanks for these
# 예측 요약문 :  great
#
#
# 원문 :  disappointed cookies pretty tasteless damn hard would buy certainly tasted much better low cal cookies definitely recommend saving money folks
# 실제 요약문 : not the best cookies have ever had
# 예측 요약문 :  great
#
#
# 원문 :  diagnosed celiac recently finding products tasty gluten free really tasty decent tasting finally found something actually tastes good crunchy texture makes feel satisfied finishing bag cookies truly delicious well worth find since god yet thankful let find
# 실제 요약문 : wow
# 예측 요약문 :  great
#
#
# 원문 :  great juice mix usually mix tablespoon two glass half way filled water stir next minute two fill glass prefer choice juice organic juice stir tiny bit pure stevia extract powder oz powder let drink sit least minutes drop cube two ice ready serve amazed
# 실제 요약문 : great in water mix
# 예측 요약문 :  great
#
#
# 원문 :  coffee really rich perfect morning ordered office going fast day decided good fine share cheap stuff brought home
# 실제 요약문 : more for me
# 예측 요약문 :  great
#
#
# 원문 :  peanut soy free yum got local keeping specialty store good came online see get less highly recommended food allergy
# 실제 요약문 : yay gluten
# 예측 요약문 :  great
#
#
# 원문 :  good cup coffee using cups months wife like coffee bold amazon reviews started coffee people jet fuel although still favorite got french roast friday sale would say new second choice also tried coffee people black tiger kona nice well rounded every day cup bold side
# 실제 요약문 : nice rich flavor
# 예측 요약문 :  great
#
#
# 원문 :  great tasting tea looking good sassafras tea forever finally ordering product thanks
# 실제 요약문 : great product
# 예측 요약문 :  great
#
#
# 원문 :  told guitar center icicle easy high quality perfectly easy nothing problems mine constant popping anything record using microphone long time perfect condition problem mic anyone else problem touch support yet say happy icicle
# 실제 요약문 : very
# 예측 요약문 :  not not the the the the the
#
#
# 원문 :  hint coconut much vanilla vanilla fan coconut fan ok
# 실제 요약문 : coffee lover
# 예측 요약문 :  great
#
#
# 원문 :  pocky got lucky couldnt stop like chocolate laced crack product good sad thing shipped stored hot room chocolate melted together partially didnt take much effort take apart sticks great product great price merchant
# 실제 요약문 : awsome
# 예측 요약문 :  the the not it
#
#
# 원문 :  weeks pregnant worst case heartburn indigestion sick till mom found tea first day drank cups symptoms bit using day heartburn indigestion day still going strong feeling better ever thank god moms tea
# 실제 요약문 : it works
# 예측 요약문 :  great
#
#
# 원문 :  bad really excited try clam chowder maine wow think campbell might even better
# 실제 요약문 : not great
# 예측 요약문 :  not not the the not it
#
#
# 원문 :  like eating large box paste enjoy flavor usually cook mix something else eating go straight box
# 실제 요약문 : good flavor but
# 예측 요약문 :  great
#
#
# 원문 :  wonderful dark chocolate flavor much flavor milk chocolate milk chocolate good deep flavor buying
# 실제 요약문 : great product
# 예측 요약문 :  great
#
#
# 원문 :  opening numerous bags found none chips flavoring completely plain gross even happen
# 실제 요약문 : off
# 예측 요약문 :  great
#
#
# 원문 :  searching hot sauces peppers compliment cuisine finally found like everything hot insanity sauce others less intense anyone wanting use sauces read instructions bottles good job dave
# 실제 요약문 : wow it is hot
# 예측 요약문 :  great
#
#
# 원문 :  brownies bake nicely would call consistency cake like however husband called healthy brownies said could taste flax seed tend agree opinion going eat chocolate want healthy taste hand love blueberry muffins hodgson mill makes
# 실제 요약문 : my husband these healthy brownies
# 예측 요약문 :  great
#
#
# 원문 :  certainly best caramels ever wish came bigger pieces finished whole box one sitting certainly buy
# 실제 요약문 : where has this candy been
# 예측 요약문 :  great
#
#
# 원문 :  strongest tasting salt vinegar chips could still vinegar flavor think close going get without vinegar powder side side cape cod salt vinegar twice flavorful additionally reviewers said quite good bit potassium
# 실제 요약문 : salty and
# 예측 요약문 :  great
#
#
# 원문 :  reading reviews got nervous opened bag recent order expecting worst worries bags great shape expiration dates chips least first bag taste like supposed good world way bags dollars ton less expensive going price around local grocery store yay team
# 실제 요약문 : favorite kettle flavor and great value
# 예측 요약문 :  great
#
#
# 원문 :  wow shocked find clear plastic pieces jars say notified earth best august still selling without checking earth best little guy taking business elsewhere sad organic company selling baby food plastic bpa jars gotta better get business
# 실제 요약문 : plastic in the food
# 예측 요약문 :  great
#
#
# 원문 :  obvious taste perfect cakes highly recommend check local michaels joann amazon usually competitive prices local craft store wayy overprice amazon com
# 실제 요약문 : so must have for cake
# 예측 요약문 :  great
#
#
# 원문 :  spicy excellent really impressed many flavors quite bit heat favorite brand milk make great thai home
# 실제 요약문 : of flavor
# 예측 요약문 :  great
#
#
# 원문 :  weigh convenience cup price taste would winner best cup cocoa planet compared making using packet pretty darn good nice nice chocolate flavor funny taste brands select oz machine though make oz otherwise watery opinion fine cup hot chocolate
# 실제 요약문 : tasty and at great price
# 예측 요약문 :  great
#
#
# 원문 :  wal mart use sell pork rinds probably years place finally found husband loves works hard figured would get something loves
# 실제 요약문 : lowery microwave pork rinds
# 예측 요약문 :  great
#
#
# 원문 :  searching tasty gluten free cookie cookie several years taste equal cookies regular eating days lucy oatmeal cookies ended quest delicious also perfect size quick snack ever satisfying calorie content also good anxious try varieties
# 실제 요약문 : finally
# 예측 요약문 :  not not the the the the the
#
#
# 원문 :  really love kettle brand chips rather disappointing little sour cream onion flavor
# 실제 요약문 : not very creamy or
# 예측 요약문 :  great
#
#
# 원문 :  love jolt remember use able get every gas station harder find happy found amazon still awesome always cannot wait get stock
# 실제 요약문 : love it
# 예측 요약문 :  great
#
#
# 원문 :  love pineapple coconut water high potassium mail hot weather afternoon get hot dry thirsty trying lose weight watching calories water wet cold thirst stuff trick quenches thirst gives little pick afternoon keeps going calories per serving much less calorie gatorade recommend looking healthy alternative sugary sports drinks
# 실제 요약문 : my up
# 예측 요약문 :  great
#
#
# 원문 :  chips pretty delicious even original flavor nothing good delicious also fried either definitely good snack times day
# 실제 요약문 : pretty delicious
# 예측 요약문 :  great
#
#
# 원문 :  generally enjoyed product years found one container far quite inferior ghee milk fat still present made bit sick threw away rest container
# 실제 요약문 : ghee
# 예측 요약문 :  not not it
#
#
# 원문 :  product made wonderful pancakes could taste difference gluten free version original tried using make pizza dough relative success texture little bit weird tasted good
# 실제 요약문 : great for pancakes
# 예측 요약문 :  not not the the the the the
#
#
# 원문 :  girlfriend bought bucks worth every penny use sandwiches instead mayo best stuff healthy fact really bad keep mind
# 실제 요약문 : so very good
# 예측 요약문 :  great
#
#
# 원문 :  us cannot digest gluten finally cookie tastes delicious easy stomach
# 실제 요약문 : delicious gluten free
# 예측 요약문 :  great
#
#
# 원문 :  thought might great idea buy meat mail turned great love thought order amazon least would make feel better whole idea order delivered days would driver could get packed ice packs could reuse taste great pretty makes great easy lunch order
# 실제 요약문 : happy now
# 예측 요약문 :  great
#
#
# 원문 :  different type coffee tried keurig coffee maker right tied newman cup favorite couple cup products seemed fine first tasted come pale somewhat comparison flavors makes really tasting coffee strong taste goes easily richness taste well bottom line purchasing supply runs continue experimenting different flavor cups
# 실제 요약문 : like this
# 예측 요약문 :  great
#
#
# 원문 :  food chicken jerky products dogs may associated illness dogs last months fda seen increase number complaints received dog illnesses associated consumption chicken jerky products imported china complaints reported fda dog owners
# 실제 요약문 : and
# 예측 요약문 :  the not it
#
#
# 원문 :  waffles mixes sweet also made scratch like waffles sugar like much sugar mix good waffles right mix easy prepare
# 실제 요약문 : not as sweet as other
# 예측 요약문 :  great
#
#
# 원문 :  actually gave local baker daughters cupcakes looked great showed perfectly white chocolate icing great shape
# 실제 요약문 : great color
# 예측 요약문 :  not not the the the the the
#
#
# 원문 :  oatmeal extremely filling hearty consistency instant oatmeal know flavor somewhat bland allows one creative add ins nutritional information great especially plant derived omega added whole flax seeds wish less added sugar though happy breakfast every morning get healthy start day
# 실제 요약문 : favorite oatmeal
# 예측 요약문 :  great
#
#
# 원문 :  variety pack way go buying bulk month old daughter loves flavors
# 실제 요약문 : nice variety
# 예측 요약문 :  great
#
#
# 원문 :  wish read product description better realize sweetened like sweetened teas stuck orders green tea powder great
# 실제 요약문 : stash tea powder review
# 예측 요약문 :  not not the the the the the
#
#
# 원문 :  pleased dog food ordered anything else dogs since bought lab poo eat happily happy healthy
# 실제 요약문 : great healthy dog food
# 예측 요약문 :  great
#
#
# 원문 :  excited get cup never made thru cup sweet sickening really find family stuff christmas long way lol
# 실제 요약문 : way two sweet
# 예측 요약문 :  great
#
#
# 원문 :  says wonderful way get fiber use snack opposed cookies chips use milk cup bowl slowly munch one square time works weight watchers plan great way get fiber soothe cookie healthy fashion
# 실제 요약문 : bought boxes what does that tell you
# 예측 요약문 :  great
#
#
# 원문 :  discovered pasta years ago canada love hard find consistently us stores second time bought seller excellent service start receipt
# 실제 요약문 : darn good pasta and fantastic customer service
# 예측 요약문 :  great
#
#
# 원문 :  got beans amount time even opened package knew going great amazing aroma beans evident actually opened packaging bought make vanilla extract say juicy beans highly recommend
# 실제 요약문 : awesome
# 예측 요약문 :  great
#
#
# 원문 :  gravey wonderful taste good one scratch except greasy
# 실제 요약문 : great
# 예측 요약문 :  great
#
#
# 원문 :  friend sent two boxes christmas thought odd gift go buy herbal tea shortly major stress family started drinking tea help unexpected stomach pains worked time family members got physically ill able carry without catching bug since believer make iced tea drink cup night bed
# 실제 요약문 : tea
# 예측 요약문 :  great
#
#
# 원문 :  review cinnamon cookie small bag love gluten issues like fact cookies gluten free crunchy satisfy desire something sweet fat three cookies pack cookies saturated fat trans fat cholesterol mg sodium fiber carbs protein yummy every bite starbucks carries glad able buy amazon
# 실제 요약문 : delicious and healthy
# 예측 요약문 :  not not the the it
#
#
# 원문 :  favorite home like ones sea salt also like barbeque flavored chips cut plain slice potatoes thick crunchy great texture mouth also great taste sea salt ones favorite enough salt salt much feel like drink gallon water chips enjoy
# 실제 요약문 : love kettle chips
# 예측 요약문 :  great
#
#
# 원문 :  year daily feed dogswell happy hips treats year old dog arthritis hips fluid without stiff look stride glucosamine chondroitin contained product plus looks forward getting treats every day also give dog best pet health chewable tablet every evening contains glucosamine chondroitin products really help arthritic dog lot
# 실제 요약문 : dogswell dogs love them
# 예측 요약문 :  great
#
#
# 원문 :  got item one day sale amazon love single serving portion following ww plan points plus per serving tasty line special crackers variety nice box last awhile cheddar bbq favorites try
# 실제 요약문 : perfect for
# 예측 요약문 :  great
#
#
# 원문 :  large bag dry pet food highly recommended adult dog also worth purchasing larger sized bag order stock food greater length time
# 실제 요약문 : excellent dog food
# 예측 요약문 :  great
#
#
# 원문 :  product received advertised twizzlers strawberry ounce bags
# 실제 요약문 : twizzlers strawberry
# 예측 요약문 :  not not the the the the the
#
#
# 원문 :  tried came home find sell west coast amazon sell ones wanted put wish list gift loved one within week birthday amazon mailed available great chips took longer ship expected time birthday want something real bad amazon usually comes
# 실제 요약문 : yum
# 예측 요약문 :  great
#
#
# 원문 :  food great year old loves much active since changed food highly recommend dog food
# 실제 요약문 : great for dogs
# 예측 요약문 :  great
#
#
# 원문 :  melitta cafe collection riviera sunset blend coffee full flavored much better decafs tried really tastes like regular coffee great enjoy aided coffee summer worries keeping us awake night recommended
# 실제 요약문 : rich flavor
# 예측 요약문 :  great
#
#
# 원문 :  energy great buying drinking year energy boost excellent continuous hour effect recent shipments seem improved flavor slightly well perhaps getting used drink flavor fake flavors found non organic energy shots
# 실제 요약문 : flavor getting better
# 예측 요약문 :  great
#
#
# 원문 :  bought brand online indian grocery store usually excellent products able turn cream butter using super blender adding water barely flavor usually buy brand coconut cream read another review different product making coconut cream complaint texture mine virtually tasteless
# 실제 요약문 : little flavor
# 예측 요약문 :  great
#
#
# 원문 :  primary reason ordering picture shown cookies green acknowledge important information heading listed warning actual product may different compared shown aside color problem shipped quickly properly one two broken cookies arrival big deal eat come anyway sure flavor delicious per description picky color good value
# 실제 요약문 : color
# 예측 요약문 :  the the not it
#
#
# 원문 :  good quality oats package came time oats worked well recipes admit single person bought oats boyfriend breakfast food lasted us year otherwise excellent buy
# 실제 요약문 : loved the oats
# 예측 요약문 :  great
#
#
# 원문 :  best tasting brown rice ever kind nutty flavor rice ever tastes great
# 실제 요약문 : fantastic
# 예측 요약문 :  great
#
#
# 원문 :  thought healthy treats found made china noted back bag concerned may fall china made jerky treats suspected cause kidney problems pets
# 실제 요약문 : made in china
# 예측 요약문 :  great
#
#
# 원문 :  gmo free due husband son eat gluten used frequently many gluten free recipes concerned use gmos corn especially family increased consumption wanted find affordable gmo free product use baking rumford natural one using months great success satisfaction
# 실제 요약문 : superior product
# 예측 요약문 :  the not it
#
#
# ...
# 실제 요약문 : this is good
# 예측 요약문 :  great
#
#
# 원문 :  love love love stuff company good quality cows grassfed use everything pricy yes worth currently country get quality butter anywhere thank god packed ghee thankful quality products like
# 실제 요약문 : love this ghee
# 예측 요약문 :  great
#
#
# 원문 :  expiration date smashed stale edible real enjoyable price paid one best pretzel purchased publix stopped carrying must find another addiction
# 실제 요약문 : bit on the stale
# 예측 요약문 :  great
#
#
# 원문 :  looking proper nutrition cereal one best period low sugar calorie high fiber protein one ask add low fat milk frozen fruit perfect breakfast wish could buy bulk
# 실제 요약문 : the best cereal in of nutrition
# 예측 요약문 :  great
#
#
# 원문 :  singles sell store box singles sure amazon selling box singles hazelnut coffee creamer favorite truly good buy
# 실제 요약문 : rip off price
# 예측 요약문 :  great
#
#
# 원문 :  bob red mill organic golden flaxseeds excellent way omega ounces delivered packs use immediately suggest storing seeds freezer keep fresh grind right use mild taste milder brown flaxseed ordered product several times quality consistently high
# 실제 요약문 : organic
# 예측 요약문 :  not not the the it
#
#
# 원문 :  water really good reasonably priced mountain spring water please order least regret priced right get ounce bottles great price use standard shipping days free shipping way buy product aware popular product sometimes amazon stock may wait weeks worth wait great product
# 실제 요약문 : water
# 예측 요약문 :  great
#
#
# 원문 :  easy grow cat loved highly recommend purchase cat love forever
# 실제 요약문 : cat grass
# 예측 요약문 :  great
#
#
# 원문 :  really liked chips came recommended friend really like variety pack great try flavors although fond cheddar bbq salt pepper chips great traditional ones get traditional chips great brother still asks around house yet purchased hint texture snack munchos
# 실제 요약문 : sooo tasty
# 예측 요약문 :  great
#
#
# 원문 :  friend favorite candy eight available anywhere area could find line either amazon com came imported england delicious peppermint thin smooth mint cream center dark chocolate shell want little taste mint really special cup hot coffee
# 실제 요약문 : impossible to find
# 예측 요약문 :  great
#
#
# 원문 :  favorite granola bar vegan gluten free difficult comes finding granola bars meet needs one absolutely delicious love ingredients strawberries throughout whole bar highly recommend
# 실제 요약문 : my favorite
# 예측 요약문 :  great
#
#
# 원문 :  eat chips often favorites flavor texture traditional tortilla chips subtle lime flavoring makes special lime flavoring appears seasoning dusted chips seem barely flavor find looking still none quite enough tastes wish chips hint lime
# 실제 요약문 : tasty
# 예측 요약문 :  great
#
#
# 원문 :  recently bought gluten free bisquick first time wonderful admit addicted pancakes light thick fluffy absolutely delicious
# 실제 요약문 : love the pancakes
# 예측 요약문 :  not not it
#
#
# 원문 :  really enjoy adding seeds smoothies add nice texture right amount crunch think taste like seeds hear healthy
# 실제 요약문 : delicious seeds
# 예측 요약문 :  great
#
#
# 원문 :  sugar substitute taste sugar substitute aftertaste turns even tried using little bit milk mug hand hide taste using swiss miss powder little milk make creamier hot chocolate using using keurig
# 실제 요약문 : after taste
# 예측 요약문 :  not not the the the the the
#
#
# 원문 :  last tastes good really like taste gone like never takes two pieces really enjoy also careful eat seriously hard swallow want try see mean
# 실제 요약문 : yummy
# 예측 요약문 :  great
#
#
# 원문 :  watered overpriced hot chocolate disappointed bad reviews lowest amount brewing still tastes watered need dump swiss miss hot chocolate give flavor point purpose product already overpriced tasting watered worth skip maybe different brand better
# 실제 요약문 : agree
# 예측 요약문 :  great
#
#
# 원문 :  found microwave pork rinds quite accident ever since something wanted found amazon could happier quick easily prepared snack reviewers bad diet come put microwave open bag pour marvel hear still popping crackling bowl may never go back bagged pork rinds ever
# 실제 요약문 : tasty snack
# 예측 요약문 :  the not not your
#
#
# 원문 :  love eating chia seeds filling put oatmeal everyday help digestive system
# 실제 요약문 : seeds
# 예측 요약문 :  great
#
#
# 원문 :  delicious hot chocolate best oz cup oz strong coffee delicious mocha
# 실제 요약문 : delicious
# 예측 요약문 :  great
#
#
# 원문 :  dont take lose weight laxative tea ones labeled weight loss tea constipated taking tea everyday helped much cramps negative effects strong dont recommend constipation losing weight warning works go
# 실제 요약문 : it works
# 예측 요약문 :  great
#
#
# 원문 :  next best thing fresh never fresh pork rinds something got try
# 실제 요약문 : great product
# 예측 요약문 :  great
#
#
# 원문 :  powder company superb small problem order gracious manner customer forever
# 실제 요약문 : the best
# 예측 요약문 :  great
#
#
# 원문 :  meant pick normal chewy chips ahoy returned home find shoved word oatmeal corner package kept everything else decided try anyway oats definitely normally wonderful chocolate dough
# 실제 요약문 : misleading packaging
# 예측 요약문 :  not not the the it
#
#
# 원문 :  oriental flavor ramen noodles taste okay almost always add ingredients make dish wholesome prepare adding sesame seed oil vegetables water adding seasoning noodles water rough vegetables like chopped onions taste better boiled seasoning minutes prior adding noodles
# 실제 요약문 : inexpensive meal
# 예측 요약문 :  great
#
#
# 원문 :  best coco water bring back drinking last years one liter pack really best unfortunatley seems discontinued shame small size product good one hope company gets common sense continues product good one large small kids upsets stomach tastes awful stars
# 실제 요약문 : best
# 예측 요약문 :  great
#
#
# 원문 :  husband love hot chocolate auto shipment every month going change every month
# 실제 요약문 : love it
# 예측 요약문 :  great
#
#
# 원문 :  great stuff made really tasty banana bread good quality lowest price town
# 실제 요약문 : bean flour
# 예측 요약문 :  great
#
#
# 원문 :  cannot detect difference also supposed free sample really ship tiny jar box mail costs postage something box costs disappointed reconsider offerings
# 실제 요약문 : not special
# 예측 요약문 :  not not the the the the the
#
#
# 원문 :  really enjoyed green tea cannot wait try making green tea latte love tassimo machine
# 실제 요약문 : great tasting green tea
# 예측 요약문 :  great
#
#
# 원문 :  many ways say yum delicious way wake morning enjoy time day
# 실제 요약문 : senseo paris french vanilla caramel coffee pods
# 예측 요약문 :  great
#
#
# 원문 :  star reviews convinced buy wish two months since purchased still four six containers unopened blah chili lime flavored almonds blue diamond hand mm mm good
# 실제 요약문 : not big fan of these
# 예측 요약문 :  not not the the the the the
#
#
# 원문 :  would buy chia seeds costco instead pounds use smoothies salads lately mix chocolate almond milk amazing pudding hours chilled
# 실제 요약문 : awesome
# 예측 요약문 :  great
#
#
# 원문 :  cats love cat grass seeds sprout easily sprinkle top kind moisture soil cats eat sprouts quickly suggest purchase multiple seed packs would sprouts ready first gobbled drawback shipping cost seed packets another reason order shipping cost several packages single packet
# 실제 요약문 : easy to grow
# 예측 요약문 :  great
#
#
# 원문 :  looking missing taste exactly taste one made india loved remember days back india definitely recommend
# 실제 요약문 : great taste
# 예측 요약문 :  not not it
#
#
# 원문 :  ordered earth best nd dinner variety pack along fruit variety pack got fruit variety pack oatmeal fruit variety pack dinner pack found cannot return item either try amazon phone help else maybe little one like stuff
# 실제 요약문 : wrong item shipped
# 예측 요약문 :  great
#
#
# 원문 :  tried many different brands green tea one far best one ever tried taste delicious tea bag tightly sealed special packet keeps totally fresh use even strings totally natural metal affect taste tea new favorite tea glad discovered
# 실제 요약문 : the very best organic green tea
# 예측 요약문 :  great
#
#
# 원문 :  drink lot flavored black teas hands one favorites scent flavor bold sweet time love spice must tea
# 실제 요약문 : most delicious tea
# 예측 요약문 :  great
#
#
# 원문 :  cookies yummy well priced recommend cookies like mrs fields chips ahoy soft baked oreos cookies
# 실제 요약문 : one of my favorite cookies
# 예측 요약문 :  great
#
#
# 원문 :  used chew gum time packets tastes good young would eat little time flavor last long tastes amazing
# 실제 요약문 : great gum
# 예측 요약문 :  great
#
#
# 원문 :  cannot find bad boys kentucky usually mom ship bag every thank goodness buy online talk mom much
# 실제 요약문 : oh boy oberto are
# 예측 요약문 :  great
#
#
# 원문 :  picky likes change food decided try two brands mistake newman really best dog looks better feels better quality food good like experiment around poor dogs stomach stick newmans
# 실제 요약문 : still the best
# 예측 요약문 :  great
#
#
# 원문 :  subscription popchips arrived time damaged love fact receive great variety chips healthier time tasty satisfying way chips packed shipping perfect subscription way go course price right thank
# 실제 요약문 : treat of the day
# 예측 요약문 :  great
#
#
# 원문 :  crisp crunchy thin low sodium usually prefer mine plain shared package friend enjoyed tuna salad topping great alternative expensive varieties sold stores excellent product rice cakes brand also wonderful salt diet sodium
# 실제 요약문 : great light cracker substitute
# 예측 요약문 :  great
#
#
# 원문 :  bars great however item purchased club box
# 실제 요약문 : so good
# 예측 요약문 :  great
#
#
# 원문 :  told treats chicken cause problems dogs wanted return unopened packages company accept returns ridiculous must know bad animals
# 실제 요약문 : no
# 예측 요약문 :  great
#
#
# 원문 :  biscuits delicious sweet enough crunch love quick delivery would order satisfied
# 실제 요약문 : delicious
# 예측 요약문 :  great
#
#
# 원문 :  colombia looking coffee tasted like back home everyday make coffee aroma whole kitchen feels like home tastes like love coffee
# 실제 요약문 : like good colombian coffee
# 예측 요약문 :  great
#
#
# 원문 :  good like several flavors cookie usually one times per week convenient eat car taking daughter school product wholesome feel good eating order frequently hope amazon continues carry
# 실제 요약문 : morning glory breakfast cookies
# 예측 요약문 :  great
#
#
# 원문 :  love pop rather small pops size pop come many flavors think bag great long run think halloween
# 실제 요약문 : love candy
# 예측 요약문 :  great
#
#
# 원문 :  taste fine cup container opened seal brewing process one occasion resulting coffee grounds never happen brand cup hope norm wolfgang puck
# 실제 요약문 : cup problem
# 예측 요약문 :  great
#
#
# 원문 :  baby love bought many times good quality good taste baby love love reccommend
# 실제 요약문 : good taste
# 예측 요약문 :  great
#
#
# 원문 :  dogs love product ends crumbly hard give dogs really great product
# 실제 요약문 : dog treats
# 예측 요약문 :  great
#
#
# 원문 :  best potato chips ever best price ever paid service shipping free
# 실제 요약문 : kettle organic chipotle potato chips
# 예측 요약문 :  great
#
#
# 원문 :  awesome wolfgang puck cups coffee smooth cups brew perfectly taste unbelievable husband hooked price great considering amazing coffee
# 실제 요약문 : can wolfgang make bad cup
# 예측 요약문 :  great
#
#
# 원문 :  perfect thing end tired day taste smooth warm creamy find look forward cup read minutes treat
# 실제 요약문 : yummy
# 예측 요약문 :  great
#
#
# 원문 :  read reviews agree yuban absolutely best coffee cans comes pay local store understand high price
# 실제 요약문 : cost is way too
# 예측 요약문 :  great
#
#
# 원문 :  sweet maui onion tastes like sour cream onion hoping get delicious chips enjoyed maui time
# 실제 요약문 : yuk
# 예측 요약문 :  great
#
#
# 원문 :  muffin mix awful taste flour sour cream used make tastes tried tried good tasting low carb treats esp diabetics
# 실제 요약문 : yuck
# 예측 요약문 :  great
#
#
# 원문 :  great sushi use bob maybe snack lightly salted great crunch support rice beef pork even fish vegetable two
# 실제 요약문 : great for snacking
# 예측 요약문 :  great
#
#
# 원문 :  good tasting pricing pretty good always sold keurig com come make purchase love dark chocolate reason stars pricing great okay
# 실제 요약문 : another yummy
# 예측 요약문 :  great
#
#
# 원문 :  great way stock cup assortment without take extra another item carousel units offered kitchen small
# 실제 요약문 : great without extra space
# 예측 요약문 :  not not the the the it
#
#
# 원문 :  cat iron stomach eat absolutely anything everything always getting human food never thrown gave treats within minutes throwing connect first gave treats next day exact reaction tried several different flavors brand reaction trying cat st time give wait see give anymore
# 실제 요약문 : my kitty to vomit
# 예측 요약문 :  great
#
#
# 원문 :  product good feeling rather highly priced know gluten free products general expensive made easily available ingredients people gluten problem eating healthy sick like muffins particularly toasted
# 실제 요약문 : good but slightly expensive
# 예측 요약문 :  great
#
#
# 원문 :  coffee light side rather medium roast think would purchase even though good value purchase
# 실제 요약문 : wolfgang puck coffee for keurig
# 예측 요약문 :  great
#
#
# 원문 :  bought local store due great ingredients none bad chemicals waiting stock definitely buy available best shortbread cookies ever son agrees love basically good could get made ingredients pronounce kill delicious
# 실제 요약문 : these are fantastic
# 예측 요약문 :  great
#
#
# 원문 :  love tea like drinking liquid red hate herbal teas taste smell like potpourri stuff awesome
# 실제 요약문 : love it
# 예측 요약문 :  great
#
#
# 원문 :  service pepperoni fantastic usual amazon cancelled order end acknowledge although got mail food returns looks like bags every months instead one
# 실제 요약문 : great product
# 예측 요약문 :  not not the the the the the
#
#
# 원문 :  strong right long time tea drinker happy come across iced tea mix serves sports drink find iced tea refreshing really like flavor especially low sugar content plain green favorite followed raspberry blueberry good unsweetened add half packet
# 실제 요약문 : not too sweet
# 예측 요약문 :  great
#
#
# 원문 :  glad able find site love flavor crunchy box packed inside another box still bags end crumbs bags tact
# 실제 요약문 : my favorite flavor
# 예측 요약문 :  great
#
#
# 원문 :  could find local stores anymore glad find amazon great tasting low fat snack
# 실제 요약문 : great snack
# 예측 요약문 :  great
#
#
# 원문 :  small lollipops arrived broken got part party favor rainbow birthday party actually tasted lollipops cute wrappers writing wish bit smaller expected arrived broken really well packaged looked cute party
# 실제 요약문 : cute
# 예측 요약문 :  not not it
#
#
# 원문 :  one thing dog likes liver biscotti dog treats make best rewards training treats used
# 실제 요약문 : make your dog happy
# 예측 요약문 :  great
#
#
# 원문 :  excellent service price product order shipped quickly received good condition ordering long price stays good really cannot beat price
# 실제 요약문 : dirty martini olive juice
# 예측 요약문 :  great
#
#
# 원문 :  well looking another coffee would meet cups using far tasted coffee cups using bought almost packages used ordering boxes soon great coffee regular guy point view
# 실제 요약문 : great coffee
# 예측 요약문 :  great
#
#
# 원문 :  recieved product time excellent shape tastes good meets expectations thanks excellent service
# 실제 요약문 : grove square cups
# 예측 요약문 :  great
#
#
# 원문 :  hot cocoa delicious strong enough make larger size find three flavors delicious favorite dark cocoa best bang buck far found hot cocoa tend use coffee maker everything coffee
# 실제 요약문 : well worth the money
# 예측 요약문 :  great
#
#
# 원문 :  giving dogs past couple years love even though bit pricey bag lasts long time dogs get treats rewards good really anything bag lasts couple weeks merrick excellent company dogs love really else matters excellent price ready buy soon
# 실제 요약문 : lamb treats the only treats for my dogs
# 예측 요약문 :  not not the the the it
#
#
# 원문 :  best popcorn ever ate use whirley popper pop popcorn eat baby white hulless never go back popcorn gave orville walmart popcorn away many cannot beat popcorn tastes sooooo good even puppy loves
# 실제 요약문 : the best
# 예측 요약문 :  great
#
#
# 원문 :  perfect transaction cannot buy candy anywhere town great find
# 실제 요약문 : perfect
# 예측 요약문 :  great
#
#
# 원문 :  would continue buy moving home made finger foods away glass jars many like flavors though great textures
# 실제 요약문 : organic and tasty
# 예측 요약문 :  great
